# %%
import matplotlib.pyplot as plt
import math
from scipy.integrate import solve_ivp
import scipy
import pandas as pd
import numpy as np

from os.path import isfile, join
import os

#from scipy.signal import savgol_filter
from matplotlib.colors import LinearSegmentedColormap

# %%
# Import for TRPL data 
import trPL_importClass
from importlib import reload

# %%
reload(trPL_importClass)
# Out:
# <module 'trPL_importClass' from '/home/qrb/Documents/Scripts/trPL_Analysis/trPL_importClass.py'>

# %%
trPLs = trPL_importClass.trPL_measurement_series(r"../Data_trPLtrSPV/Maxim/S3", BG = 1.55, thickness = 450e-9, TRPL_denoise = -50, mode = "wannsee", 
                                                    retime = False, importPL=True, importSPV=True)
# Out:
# Lambda Laser set to: 7.050000e-07
# Spot diameter set to: 2.720000e-04
# Film thickness set to: 4.500000e-07
# Beam dump ratio set to: 1.000000e+00
# BG, Nc and Nv set to:1.55 2e+18 2e+18
# ['M00-trPL-S3-1800s-ND2-BE-A2-1kHz.csv', 'M01-trPL-S3-1800s-ND1-BE-A4-1kHz.csv', 'M02-trPL-S3-1800s-ND0-BE-A3ND3-1kHz.csv', 'M03-trPL-S3-1800s-ND0-BE-A3ND3-1kHz.csv', 'M04-trPL-S3-1800s-ND1-BE-A3-1kHz.csv', 'M05-trPL-S3-1800s-ND2-BE-A1-1kHz.csv']

# %%
trPLs.TRPL_binsize
# Out:
# [np.float64(5.12e-10),
#  np.float64(5.12e-10),
#  np.float64(5.12e-10),
#  np.float64(5.12e-10),
#  np.float64(5.12e-10),
#  np.float64(5.12e-10)]

# %%
trPLs.SPVs
# Out:
#          M00E_S3_ND2_2025-07-10_0_181910.Wfm.csv: time [s]  \
# 0                                            -8.720000e-08
# 1                                            -8.680000e-08
# 2                                            -8.640000e-08
# 3                                            -8.600000e-08
# 4                                            -8.560000e-08
# ...                                                    ...
# 9999995                                                NaN
# 9999996                                                NaN
# 9999997                                                NaN
# 9999998                                                NaN
# 9999999                                                NaN
#
#          M00E_S3_ND2_2025-07-10_0_181910.Wfm.csv: voltage [V]  \
# 0                                                 0.013713
# 1                                                 0.013710
# 2                                                 0.013709
# ...
